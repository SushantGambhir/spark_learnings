# %% [markdown]
# ### 🔗 Links and Resources
#
# #### Azure
# - [Azure Sign Up](https://azure.microsoft.com)
# - [Azure Portal](https://portal.azure.com/)
# - [Azure Portal Overview](https://learn.microsoft.com/en-us/azure/azure-portal/azure-portal-overview)
# - [Azure Resource Hierarchy](https://learn.microsoft.com/en-us/azure/cloud-adoption-framework/ready/azure-setup-guide/organize-resources#build-a-management-hierarchy)
# - [Azure Built-in Roles](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles)
# - [Entra ID Roles](https://learn.microsoft.com/en-gb/entra/identity/role-based-access-control/permissions-reference)
#
# #### Azure Data Lake Storage Gen2
# - [Introduction to Azure Data Lake Storage (MS Learn)](https://learn.microsoft.com/en-us/training/modules/introduction-to-azure-data-lake-storage/)
# - [Introduction to Azure Data Lake Storage (MS Docs)](https://learn.microsoft.com/en-us/azure/storage/blobs/data-lake-storage-introduction)
