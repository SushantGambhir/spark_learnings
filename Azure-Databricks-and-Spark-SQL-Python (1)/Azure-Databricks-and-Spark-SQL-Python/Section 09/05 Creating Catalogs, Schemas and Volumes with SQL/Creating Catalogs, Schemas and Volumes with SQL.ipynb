# %% [markdown]
# ### 🔗 Links and Resources
# - [CREATE CATALOG](https://learn.microsoft.com/en-us/azure/databricks/schemas/create-catalog)
# - [CREATE SCHEMA](https://learn.microsoft.com/en-us/azure/databricks/schemas/create-schema)
# - [CREATE VOLUME](https://learn.microsoft.com/en-us/azure/databricks/schemas/create-volume)

# %% [markdown]
# ### 📌 Syntax

# %%
# %sql

-- Creating a Catalog
-- Managed Location is mandatory if a storage root URL has not been configured for the Metastore

CREATE CATALOG [ IF NOT EXISTS ] <catalog-name>
   [ MANAGED LOCATION '<location-path>' ]
   [ COMMENT <comment> ];

# %%
# %sql
CREATE CATALOG test_catalog

MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragegiudqtilr74nq.dfs.core.windows.net/7405606720484138'

# %%
# %sql

-- Creating a Schema

CREATE { DATABASE | SCHEMA } [ IF NOT EXISTS ] <catalog-name>.<schema-name>
    [ MANAGED LOCATION '<location-path>' | LOCATION '<location-path>']
    [ COMMENT <comment> ]
    [ WITH DBPROPERTIES ( <property-key = property_value [ , ... ]> ) ];

# %%
# %sql
CREATE SCHEMA test_catalog.test_schema

# %%
# %sql

-- Creating a Volume

CREATE VOLUME <catalog>.<schema>.<volume-name>
LOCATAION '<location-path>'

# %%
# %sql
CREATE VOLUME test_catalog.test_schema.test_volume
