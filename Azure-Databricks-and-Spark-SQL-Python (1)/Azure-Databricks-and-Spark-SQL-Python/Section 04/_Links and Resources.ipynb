# %% [markdown]
# ### 🔗 Links and Resources
#
# - [Databricks Notebooks Overview](https://learn.microsoft.com/en-us/azure/databricks/notebooks/)
# - [Develop code in Databricks notebooks](https://learn.microsoft.com/en-us/azure/databricks/notebooks/notebooks-code#language-magic)
