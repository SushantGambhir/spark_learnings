# %% [markdown]
# ### 🔗 Links and Resources
#
# - [What is a Lakehouse?](https://learn.microsoft.com/en-us/azure/databricks/lakehouse/)
# - [Databricks Concepts](https://learn.microsoft.com/en-us/azure/databricks/getting-started/concepts)
# - [Understanding Databases, Warehouses, Lakes, and Lakehouses](https://www.youtube.com/watch?v=70578em7fIc)
