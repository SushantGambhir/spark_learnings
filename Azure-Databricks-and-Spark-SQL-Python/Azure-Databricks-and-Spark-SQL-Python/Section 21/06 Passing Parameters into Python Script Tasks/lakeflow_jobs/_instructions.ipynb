# %% [markdown]
# ### 🔗 Links and Resources
# - [Lakeflow Jobs](https://learn.microsoft.com/en-us/azure/databricks/jobs/)

# %% [markdown]
# ### 📌 Instructions
#
# In this directory you’ll find two python scripts:
#
# 1. **`python_script_01`**
# 2. **`python_script_02`**
#
# **What was covered in the lecture:**
# - I defined a Lakeflow Job with **two Python Script Tasks**:
#   - **task_01_python_script:** Execute `python_script_01`.
#   - **task_02_python_script:** Execute `python_script_02`.
# - Configure **task_02_python_script** to run **task_01_python_script** Task A completes **successfully**.
#
# **Serverless compute** was used in the demo with Performance Optimization enabled.
#
# **Parameters:**
# I provided parameters in the task definitions `["John", "{{workspace.id}}"]` and retrieved them using the `sys` module
