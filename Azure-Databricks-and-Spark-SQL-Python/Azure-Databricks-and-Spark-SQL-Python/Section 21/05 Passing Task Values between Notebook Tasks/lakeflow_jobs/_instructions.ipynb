# %% [markdown]
# ### 🔗 Links and Resources
# - [dbutils.jobs.taskValues](https://learn.microsoft.com/en-us/azure/databricks/dev-tools/databricks-utils#dbutils-jobs-taskvalues)
# - [Use task values to pass information between tasks](https://learn.microsoft.com/en-us/azure/databricks/jobs/task-values?source=recommendations)

# %% [markdown]
# ### 📌 Instructions
#
# In this directory you’ll find two notebooks scripts:
#
# 1. **`notebook_01`**
# 2. **`notebook_02`**
#
# **What was covered in the lecture:**
# - I defined a Lakeflow Job with **two Notebook Tasks**:
#   - **task_01_notebook:** Execute `notebook_01`.
#   - **task_02_notebook:** Execute `notebook_02`.
# - Configure **task_02_notebook** to run **task_01_notebook** Task A completes **successfully**.
#
# **Serverless compute** was used in the demo with Performance Optimization enabled.
#
# I added various task and job level parameters:
# - **football_team**
# - **task_run_id**
#
# I added task values:
# - **fave_tv_show**
#
# Please ensure you follow along with the lecture.
