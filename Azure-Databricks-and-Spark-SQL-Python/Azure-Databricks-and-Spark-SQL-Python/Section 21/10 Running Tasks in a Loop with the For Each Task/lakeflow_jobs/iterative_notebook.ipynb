# %%
region_name = dbutils.widgets.get("region_name")

# %%
print(region_name)

# %%
display(
    spark.read.table("population_metrics.default.countries_consolidated")
         .filter(f"region = '{region_name}'")
)
