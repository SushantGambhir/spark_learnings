# %% [markdown]
# ### 🔗 Links and Resources
# - [write](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.write.html)
# - [csv()](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrameWriter.csv.html)
# - [save()](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrameWriter.save.html)
# - [mode](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrameWriter.mode.html)

# %% [markdown]
# ### 📌 Reading data into a Spark DataFrame
# This DataFrame will be written as a CSV output

# %%
path = "/Volumes/population_metrics/landing/datasets/countries_dataset/countries_dataset/csv_data/countries_population/countries_population.csv"

df = spark.read.format("csv").options(header=True).load(path)

df.display()

# %% [markdown]
# ### 📌 Using the csv() method

# %%
output_path = "/Volumes/population_metrics/landing/datasets/output_dataset/csv/countries_population"

# %%
# This is a DataFrameWriter object, you can apply the csv or save methods to it
df.write

# %%
# Writing the DataFrame to CSV
df.write.csv(output_path)

# %% [markdown]
# %md
# ### 📌 Append vs Overwrite
#
# When the target directory already contains data, specify a write mode:
#
# - **overwrite**: delete existing files before writing the new output
# - **append**: keep existing files and add the new output alongside them
#
# Using **append** lets you incrementally add new data to the destination as it arrives.

# %%
# mode as append and header=True
df.write.mode("append").options(header=True).csv(output_path)

# %%
# mode as overwrite and header=True
df.write.mode("overwrite").options(header=True).csv(output_path)

# %% [markdown]
# ### 📌 Using the save() method

# %%
df.write.format("csv").mode("append").options(header=True).save(output_path)

# %%
# Changing the delimiter to the pipe symbol (|)
df.write.format("csv").mode("overwrite").options(header=True, sep="|").save(output_path)
