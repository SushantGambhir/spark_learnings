# %% [markdown]
# ### 🔗 Links and Resources
# - [Delta Lake Transaction Log](https://www.databricks.com/blog/2019/08/21/diving-into-delta-lake-unpacking-the-transaction-log.html)

# %% [markdown]
# ### 📌 Inspecting the Delta Log After executing each code cell one by one
